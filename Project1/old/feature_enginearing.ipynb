# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_data_path = './dataset/train_data.csv'
train_data = pd.read_csv(train_data_path)
X = train_data.drop(columns=['Competitor', 'Labels'])
y = train_data['Labels']
train_data
# Out:
#             Competitor        Age  Height  Weight        BMI  Nation  Year  \
# 0           Mel PENDER  30.951403   165.0    68.0  24.977043      21  1968
# 1           Mel PENDER  30.954141   165.0    68.0  24.977043      21  1968
# 2           Mel PENDER  30.954141   165.0    68.0  24.977043      21  1968
# 3    Enrique FIGUEROLA  30.247775   167.0    67.0  24.023809       8  1968
# 4    Enrique FIGUEROLA  30.250513   167.0    67.0  24.023809       8  1968
# ..                 ...        ...     ...     ...        ...     ...   ...
# 305         Usain BOLT  29.982204   196.0    95.0  24.729279      13  2016
# 306         Usain BOLT  29.982204   196.0    95.0  24.729279      13  2016
# 307    Yoshihide KIRYU  20.662560   175.0    69.0  22.530612      14  2016
# 308         Zhenye XIE  22.989733   184.0    78.0  23.038752       6  2016
# 309         Zhenye XIE  22.992471   184.0    78.0  23.038752       6  2016
#
#      Month  Hometown  WIND  Labels
# ...

# %%
def plot(col):
    global X, y
    plt.scatter(X[col], y)
    plt.xlabel(col)
    plt.ylabel('Record (s)')
    plt.plot

# %%
plot('Nation')
